# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import cv2

import numpy as np
import pandas as pd

df = pd.read_csv('data/driving_log.csv', skipinitialspace=True)
df.columns = ('center', 'left', 'right', 'steering', 'throttle', 'brake', 'speed')

# %%
steering = df['steering']
len(steering)
# Out:
# 8036

# %%
smooth_steering = df.ewm(span=5).mean()['steering']

# %%
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
FIGSIZE=(16, 8)
steering.plot.line(figsize=FIGSIZE)
smooth_steering.plot.line(figsize=FIGSIZE)

# %%
steering.plot.hist(figsize=FIGSIZE, bins=50)
#smooth_steering.plot.hist(figsize=FIGSIZE, bins=50)

# %%
image = mpimg.imread('data/IMG/center_2016_12_01_13_46_35_787.jpg')
print('This image is:', type(image), 'with dimensions:', image.shape)
plt.imshow(image)
# Out:
# This image is: <class 'numpy.ndarray'> with dimensions: (160, 320, 3)

# %%
def canny(img, low_threshold=50, high_threshold=150):
    kernel_size = 3
    img = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
    img = cv2.GaussianBlur(img, (kernel_size, kernel_size), 0)
    return cv2.Canny(img, low_threshold, high_threshold)

plt.imshow(canny(image), cmap='gray')
